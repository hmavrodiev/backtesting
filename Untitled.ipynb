# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyrenko
import scipy.optimize as opt
from scipy.stats import iqr
import talib

from catalyst import run_algorithm
from catalyst.api import (record, symbol, order_target, order_target_percent, get_datetime)

# %%
def initialize(context):
    context.asset = symbol('iot_usd')

    context.leverage = 1.0              # 1.0 - no leverage
    context.n_history = 24 * 15         # Number of lookback bars for modelling
    context.tf = '60T'                  # How many minutes in a timeframe
    context.model = pyrenko.renko()     # Renko object
    context.part_cover_ratio = 0.166    # Partially cover position ratio
    context.last_brick_size = 0.0       # Last optimal brick size (just for storing)
    
    context.set_benchmark(context.asset)
    context.set_commission(maker = 0.001, taker = 0.002)
    context.set_slippage(slippage = 0.0005)

# %%
# Function for optimization
def evaluate_renko(brick, history, column_name):
    renko_obj = pyrenko.renko()
    renko_obj.set_brick_size(brick_size = brick, auto = False)
    renko_obj.build_history(prices = history)
    return renko_obj.evaluate()[column_name]

def handle_data(context, data):
    current_time = get_datetime().time()
    if current_time.hour == 0 and current_time.minute == 0:
        print('Current date is ' + str(get_datetime().date()))

    # When model is empty
    if len(context.model.get_renko_prices()) == 0:
        context.model = pyrenko.renko()
        history = data.history(context.asset,
            'price',
            bar_count = context.n_history, 
            frequency = context.tf
            )

        # Get daily absolute returns
        diffs = history.diff(24).abs()
        diffs = diffs[~np.isnan(diffs)]
        # Calculate IQR of daily returns
        iqr_diffs = np.percentile(diffs, [25, 75])

        # Find the optimal brick size
        opt_bs = opt.fminbound(lambda x: -evaluate_renko(brick = x,
            history = history, column_name = 'score'),
        iqr_diffs[0], iqr_diffs[1], disp=0)

        # Build the model
        print('REBUILDING RENKO: ' + str(opt_bs))
        context.last_brick_size = opt_bs
        context.model.set_brick_size(brick_size = opt_bs, auto = False)
        context.model.build_history(prices = history)
        
        # Open a position
        order_target_percent(context.asset, context.leverage * context.model.get_renko_directions()[-1])

        # Store some information
        record(
            rebuilding_status = 1,
            brick_size = context.last_brick_size,
            price = history[-1],
            renko_price = context.model.get_renko_prices()[-1],
            num_created_bars = 0,
            amount = context.portfolio.positions[context.asset].amount
        )

    else:
        last_price = data.history(context.asset,
                              'price',
                              bar_count = 1,
                              frequency = '1440T',
                              )

        # Just for output and debug
        prev = context.model.get_renko_prices()[-1]
        prev_dir = context.model.get_renko_directions()[-1]
        num_created_bars = context.model.do_next(last_price)
        if num_created_bars != 0:
            print('New Renko bars created')
            print('last price: ' + str(last_price))
            print('previous Renko price: ' + str(prev))
            print('current Renko price: ' + str(context.model.get_renko_prices()[-1]))
            print('direction: ' + str(prev_dir))
            print('brick size: ' + str(context.model.brick_size))

        # Store some information
        record(
            rebuilding_status = 0,
            brick_size = context.last_brick_size,
            price = last_price,
            renko_price = context.model.get_renko_prices()[-1],
            num_created_bars = num_created_bars,
            amount = context.portfolio.positions[context.asset].amount
        )

        # If the last price moves in the backward direction we should rebuild the model
        if np.sign(context.portfolio.positions[context.asset].amount * context.model.get_renko_directions()[-1]) == -1:
            order_target_percent(context.asset, 0.0)
            context.model = pyrenko.renko()
        # or we cover the part of the position
        elif context.part_cover_ratio > 0.0 and num_created_bars != 0:
            order_target(context.asset, context.portfolio.positions[context.asset].amount * (1.0 - context.part_cover_ratio))

# %%
def analyze(context, perf):
    # Summary output
    print('Total return: ' + str(perf.algorithm_period_return[-1]))
    print('Sortino coef: ' + str(perf.sortino[-1]))
    print('Max drawdown: ' + str(np.min(perf.max_drawdown)))
    print('Alpha: ' + str(perf.alpha[-1]))
    print('Beta: ' + str(perf.beta[-1]))
    perf.to_csv('perf_' + str(context.asset) + '.csv')
    
    f = plt.figure(figsize = (7.2, 7.2))

    # Plot performance
    ax1 = f.add_subplot(611)
    ax1.plot(perf.algorithm_period_return, 'blue')
    ax1.plot(perf.benchmark_period_return, 'red')
    ax1.set_title('Performance')
    ax1.set_xlabel('Time')
    ax1.set_ylabel('Return')

    # Plot price and renko price
    ax2 = f.add_subplot(612, sharex = ax1)
    ax2.plot(perf.price, 'grey')
    ax2.plot(perf.renko_price, 'yellow')
    ax2.set_title(context.asset)
    ax2.set_xlabel('Time')
    ax2.set_ylabel('Price')

    # Plot brick size
    ax3 = f.add_subplot(613, sharex = ax1)
    ax3.plot(perf.brick_size, 'blue')
    xcoords = perf.index[perf.rebuilding_status == 1]
    for xc in xcoords:
        ax3.axvline(x = xc, color = 'red')
    ax3.set_title('Brick size and rebuilding status')
    ax3.set_xlabel('Time')
    ax3.set_ylabel('Size and Status')

    # Plot renko_price
    ax4 = f.add_subplot(614, sharex = ax1)
    ax4.plot(perf.num_created_bars, 'green')
    ax4.set_title('Number of created Renko bars')
    ax4.set_xlabel('Time')
    ax4.set_ylabel('Amount')

    # Plot amount of asset in portfolio
    ax5 = f.add_subplot(615, sharex = ax1)
    ax5.plot(perf.amount, 'black')
    ax5.set_title('Asset amount in portfolio')
    ax5.set_xlabel('Time')
    ax5.set_ylabel('Amount')

    # Plot drawdown
    ax6 = f.add_subplot(616, sharex = ax1)
    ax6.plot(perf.max_drawdown, 'yellow')
    ax6.set_title('Max drawdown')
    ax6.set_xlabel('Time')
    ax6.set_ylabel('Drawdown')

    plt.show()

# %%
run_algorithm(
    capital_base = 100,
    data_frequency = 'daily',
    initialize = initialize,
    handle_data = handle_data,
    analyze = analyze,
    exchange_name = 'bitfinex',
    quote_currency = 'usd',
    start = pd.to_datetime('2018-12-1', utc = True),
    end = pd.to_datetime('2019-4-22', utc = True))
# Out:
# [2019-04-26 19:53:23.887958] INFO: run_algo: Catalyst version 0.5.21
# [2019-04-26 19:53:23.897958] WARNING: run_algo: Catalyst is currently in ALPHA. It is going through rapid development and it is subject to errors. Please use carefully. We encourage you to report any issue on GitHub: https://github.com/enigmampc/catalyst/issues
# [2019-04-26 19:53:26.897962] INFO: run_algo: running algo in backtest mode
# [2019-04-26 19:53:26.897962] INFO: exchange_algorithm: initialized trading algorithm in backtest mode
# REBUILDING RENKO: 0.01929170825693599
# New Renko bars created
# last price: 2018-12-06 00:00:00+00:00    0.2563
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.30607975045838404
# current Renko price: 0.26749633394451205
# direction: 1
# brick size: 0.01929170825693599
# REBUILDING RENKO: 0.01704278731188387
# New Renko bars created
# last price: 2018-12-15 00:00:00+00:00    0.2148
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2362632761286969
# current Renko price: 0.21922048881681305
# direction: -1
# brick size: 0.01704278731188387
# New Renko bars created
# last price: 2018-12-18 00:00:00+00:00    0.26
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.21922048881681305
# current Renko price: 0.2533060634405808
# direction: -1
# brick size: 0.01704278731188387
# REBUILDING RENKO: 0.012194898203341874
# New Renko bars created
# last price: 2018-12-21 00:00:00+00:00    0.35305
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2965997964066836
# current Renko price: 0.345379389220051
# direction: 1
# brick size: 0.012194898203341874
# New Renko bars created
# last price: 2018-12-24 00:00:00+00:00    0.36825
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.345379389220051
# current Renko price: 0.35757428742339287
# direction: 1
# brick size: 0.012194898203341874
# New Renko bars created
# last price: 2018-12-28 00:00:00+00:00    0.32191
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.35757428742339287
# current Renko price: 0.3331844910167091
# direction: 1
# brick size: 0.012194898203341874
# REBUILDING RENKO: 0.021523837984066048
# New Renko bars created
# last price: 2019-01-02 00:00:00+00:00    0.37752
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.3300991899203302
# current Renko price: 0.3731468658884623
# direction: -1
# brick size: 0.021523837984066048
# REBUILDING RENKO: 0.01930545809350024
# New Renko bars created
# last price: 2019-01-11 00:00:00+00:00    0.31318
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.3953672404675013
# current Renko price: 0.31814540809350034
# direction: 1
# brick size: 0.01930545809350024
# REBUILDING RENKO: 0.01343234917351397
# New Renko bars created
# last price: 2019-01-14 00:00:00+00:00    0.28828
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.31993000000000005
# current Renko price: 0.29306530165297207
# direction: -1
# brick size: 0.01343234917351397
# New Renko bars created
# last price: 2019-01-28 00:00:00+00:00    0.273
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.29306530165297207
# current Renko price: 0.2796329524794581
# direction: -1
# brick size: 0.01343234917351397
# New Renko bars created
# last price: 2019-01-29 00:00:00+00:00    0.2591
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2796329524794581
# current Renko price: 0.2662006033059441
# direction: -1
# brick size: 0.01343234917351397
# New Renko bars created
# last price: 2019-02-07 00:00:00+00:00    0.24523
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2662006033059441
# current Renko price: 0.2527682541324301
# direction: -1
# brick size: 0.01343234917351397
# New Renko bars created
# last price: 2019-02-09 00:00:00+00:00    0.28308
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2527682541324301
# current Renko price: 0.279632952479458
# direction: -1
# brick size: 0.01343234917351397
# REBUILDING RENKO: 0.00848008331843872
# New Renko bars created
# last price: 2019-02-19 00:00:00+00:00    0.31035
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2789499166815613
# current Renko price: 0.30439016663687757
# direction: 1
# brick size: 0.00848008331843872
# New Renko bars created
# last price: 2019-02-21 00:00:00+00:00    0.3189
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.30439016663687757
# current Renko price: 0.3128702499553163
# direction: 1
# brick size: 0.00848008331843872
# New Renko bars created
# last price: 2019-02-24 00:00:00+00:00    0.32442
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.3128702499553163
# current Renko price: 0.32135033327375506
# direction: 1
# brick size: 0.00848008331843872
# New Renko bars created
# last price: 2019-02-25 00:00:00+00:00    0.28505
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.32135033327375506
# current Renko price: 0.2874300000000002
# direction: 1
# brick size: 0.00848008331843872
# REBUILDING RENKO: 0.005349877608082459
# New Renko bars created
# last price: 2019-03-02 00:00:00+00:00    0.3
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2935996328242474
# current Renko price: 0.29894951043232987
# direction: 1
# brick size: 0.005349877608082459
# New Renko bars created
# last price: 2019-03-05 00:00:00+00:00    0.27803
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.29894951043232987
# current Renko price: 0.2828998776080825
# direction: 1
# brick size: 0.005349877608082459
# REBUILDING RENKO: 0.0032792559471799946
# New Renko bars created
# last price: 2019-03-09 00:00:00+00:00    0.2806
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.2885737202641001
# current Renko price: 0.28201520836974014
# direction: 1
# brick size: 0.0032792559471799946
# REBUILDING RENKO: 0.007261165002250979
# New Renko bars created
# last price: 2019-03-15 00:00:00+00:00    0.3029
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.29066766999549803
# current Renko price: 0.297928834997749
# direction: 1
# brick size: 0.007261165002250979
# New Renko bars created
# last price: 2019-03-17 00:00:00+00:00    0.31029
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.297928834997749
# current Renko price: 0.30519
# direction: 1
# brick size: 0.007261165002250979
# New Renko bars created
# last price: 2019-03-22 00:00:00+00:00    0.31809
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.30519
# current Renko price: 0.312451165002251
# direction: 1
# brick size: 0.007261165002250979
# New Renko bars created
# last price: 2019-03-27 00:00:00+00:00    0.29772
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.312451165002251
# current Renko price: 0.297928834997749
# direction: 1
# brick size: 0.007261165002250979
# REBUILDING RENKO: 0.00471552681910104
# New Renko bars created
# last price: 2019-03-30 00:00:00+00:00    0.31461
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.30810210727640414
# current Renko price: 0.31281763409550517
# direction: 1
# brick size: 0.00471552681910104
# New Renko bars created
# last price: 2019-04-02 00:00:00+00:00    0.32512
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.31281763409550517
# current Renko price: 0.32224868773370724
# direction: 1
# brick size: 0.00471552681910104
# New Renko bars created
# last price: 2019-04-03 00:00:00+00:00    0.35529
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.32224868773370724
# current Renko price: 0.3552573754674145
# direction: 1
# brick size: 0.00471552681910104
# New Renko bars created
# last price: 2019-04-04 00:00:00+00:00    0.3387
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.3552573754674145
# current Renko price: 0.3411107950101114
# direction: 1
# brick size: 0.00471552681910104
# REBUILDING RENKO: 0.004923527846140482
# New Renko bars created
# last price: 2019-04-06 00:00:00+00:00    0.35741
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.33277116707684284
# current Renko price: 0.3573888063075452
# direction: -1
# brick size: 0.004923527846140482
# REBUILDING RENKO: 0.010077252577726603
# [2019-04-26 19:53:28.687964] INFO: Performance: Simulated 143 trading days out of 143.
# [2019-04-26 19:53:28.687964] INFO: Performance: first open: 2018-12-01 00:00:00+00:00
# [2019-04-26 19:53:28.687964] INFO: Performance: last close: 2019-04-22 23:59:00+00:00
# New Renko bars created
# last price: 2019-04-12 00:00:00+00:00    0.32201
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.35420901031090646
# current Renko price: 0.32397725257772664
# direction: 1
# brick size: 0.010077252577726603
# REBUILDING RENKO: 0.011245026390994787
# New Renko bars created
# last price: 2019-04-16 00:00:00+00:00    0.30294
# Freq: 1440T, Name: TradingPair(652614 [iot_usd]), dtype: float64
# previous Renko price: 0.3200450263909948
# current Renko price: 0.3088
# direction: -1
# brick size: 0.011245026390994787
# Total return: -0.450578842523938
# Sortino coef: -1.701898714629476
# Max drawdown: -0.5527636422435909
# Alpha: -0.9233489720920053
# Beta: 0.1683072471708555
#                            algo_volatility  algorithm_period_return     alpha  \
# 2018-12-01 23:59:00+00:00              NaN                 0.000000       NaN
# 2018-12-02 23:59:00+00:00         0.027492                -0.002449 -0.414311
# 2018-12-03 23:59:00+00:00         0.657106                -0.075160 -3.638951
# 2018-12-04 23:59:00+00:00         0.651151                -0.055393 -2.055665
# 2018-12-05 23:59:00+00:00         0.715467                -0.126727 -2.406629
# 2018-12-06 23:59:00+00:00         0.797223                -0.213407 -2.507908
# 2018-12-07 23:59:00+00:00         0.801558                -0.199353 -1.932775
# 2018-12-08 23:59:00+00:00         0.758215                -0.201290 -0.974266
# 2018-12-09 23:59:00+00:00         0.716469                -0.237903 -4.298760
# 2018-12-10 23:59:00+00:00         0.720230                -0.221910 -3.041413
# 2018-12-11 23:59:00+00:00         0.747184                -0.191286 -1.602352
# 2018-12-12 23:59:00+00:00         0.719994                -0.224292 -3.301252
# 2018-12-13 23:59:00+00:00         0.770753                -0.179037 -2.004036
# 2018-12-14 23:59:00+00:00         0.760559                -0.156919 -1.277827
# 2018-12-15 23:59:00+00:00         0.738681                -0.185195 -2.210595
# 2018-12-16 23:59:00+00:00         0.713795                -0.192285 -2.247972
# 2018-12-17 23:59:00+00:00         0.811948                -0.291608 -4.900676
# 2018-12-18 23:59:00+00:00         0.913086                -0.392351 -6.168341
# 2018-12-19 23:59:00+00:00         0.927660                -0.362813 -5.349925
# 2018-12-20 23:59:00+00:00         0.905338                -0.364794 -4.633710
# 2018-12-21 23:59:00+00:00         0.907182                -0.416620 -5.629575
# 2018-12-22 23:59:00+00:00         0.954357                -0.369020 -4.461117
# 2018-12-23 23:59:00+00:00         0.960542                -0.336972 -3.718412
# 2018-12-24 23:59:00+00:00         0.939552                -0.350613 -3.801554
# 2018-12-25 23:59:00+00:00         0.934116                -0.394416 -4.446617
# 2018-12-26 23:59:00+00:00         0.916607                -0.395678 -4.294461
# 2018-12-27 23:59:00+00:00         0.901610                -0.420318 -4.554935
# 2018-12-28 23:59:00+00:00         0.999901                -0.340960 -3.504591
# 2018-12-29 23:59:00+00:00         0.983742                -0.362932 -3.657747
# 2018-12-30 23:59:00+00:00         0.967157                -0.364557 -3.574479
# ...                                    ...                      ...       ...
# 2019-03-24 23:59:00+00:00         0.666907                -0.423808 -1.060649
# 2019-03-25 23:59:00+00:00         0.664367                -0.434943 -1.084069
# 2019-03-26 23:59:00+00:00         0.661472                -0.437457 -1.081993
# 2019-03-27 23:59:00+00:00         0.659927                -0.423797 -1.034824
# 2019-03-28 23:59:00+00:00         0.657104                -0.426837 -1.035290
# 2019-03-29 23:59:00+00:00         0.654317                -0.428295 -1.037205
# 2019-03-30 23:59:00+00:00         0.651573                -0.432006 -1.040298
# 2019-03-31 23:59:00+00:00         0.648887                -0.431542 -1.030355
# 2019-04-01 23:59:00+00:00         0.648467                -0.412277 -0.965840
# 2019-04-02 23:59:00+00:00         0.657118                -0.364480 -0.835062
# 2019-04-03 23:59:00+00:00         0.656772                -0.390910 -0.899758
# 2019-04-04 23:59:00+00:00         0.654171                -0.396367 -0.906553
# 2019-04-05 23:59:00+00:00         0.654198                -0.373177 -0.849862
# 2019-04-06 23:59:00+00:00         0.651597                -0.374704 -0.838909
# 2019-04-07 23:59:00+00:00         0.651645                -0.402482 -0.930260
# 2019-04-08 23:59:00+00:00         0.649095                -0.403960 -0.923926
# 2019-04-09 23:59:00+00:00         0.647276                -0.418741 -0.957570
# 2019-04-10 23:59:00+00:00         0.644885                -0.425499 -0.968904
# 2019-04-11 23:59:00+00:00         0.648245                -0.463498 -1.071326
# 2019-04-12 23:59:00+00:00         0.645857                -0.461781 -1.058339
# 2019-04-13 23:59:00+00:00         0.643463                -0.466596 -1.065062
# 2019-04-14 23:59:00+00:00         0.641061                -0.467917 -1.058704
# 2019-04-15 23:59:00+00:00         0.642898                -0.441224 -0.937007
# 2019-04-16 23:59:00+00:00         0.641412                -0.456998 -0.990921
# 2019-04-17 23:59:00+00:00         0.639276                -0.452389 -0.965146
# 2019-04-18 23:59:00+00:00         0.636957                -0.453923 -0.964387
# 2019-04-19 23:59:00+00:00         0.634701                -0.452970 -0.953646
# 2019-04-20 23:59:00+00:00         0.632435                -0.455899 -0.958514
# 2019-04-21 23:59:00+00:00         0.630759                -0.446848 -0.915280
# 2019-04-22 23:59:00+00:00         0.628550                -0.450579 -0.923349
#
#                                amount  benchmark_period_return  \
# 2018-12-01 23:59:00+00:00    0.000000                 0.042318
# 2018-12-02 23:59:00+00:00  333.333333                 0.020719
# 2018-12-03 23:59:00+00:00  333.333333                -0.055069
# 2018-12-04 23:59:00+00:00  333.333333                -0.034466
# 2018-12-05 23:59:00+00:00  333.333333                -0.108818
# 2018-12-06 23:59:00+00:00  333.333333                -0.199167
# 2018-12-07 23:59:00+00:00    0.000000                -0.182475
# 2018-12-08 23:59:00+00:00 -340.266289                -0.208742
# 2018-12-09 23:59:00+00:00 -340.266289                -0.171357
# 2018-12-10 23:59:00+00:00 -340.266289                -0.187687
# 2018-12-11 23:59:00+00:00 -340.266289                -0.218956
# 2018-12-12 23:59:00+00:00 -340.266289                -0.185255
# 2018-12-13 23:59:00+00:00 -340.266289                -0.231464
# 2018-12-14 23:59:00+00:00 -340.266289                -0.254048
# 2018-12-15 23:59:00+00:00 -340.266289                -0.225175
# 2018-12-16 23:59:00+00:00 -283.782085                -0.218261
# 2018-12-17 23:59:00+00:00 -283.782085                -0.096658
# 2018-12-18 23:59:00+00:00 -283.782085                 0.026683
# 2018-12-19 23:59:00+00:00    0.000000                -0.011952
# 2018-12-20 23:59:00+00:00  224.061936                 0.228511
# 2018-12-21 23:59:00+00:00  224.061936                 0.148148
# 2018-12-22 23:59:00+00:00  186.867655                 0.222465
# 2018-12-23 23:59:00+00:00  186.867655                 0.282051
# 2018-12-24 23:59:00+00:00  186.867655                 0.256688
# 2018-12-25 23:59:00+00:00  155.847624                 0.175735
# 2018-12-26 23:59:00+00:00  155.847624                 0.172921
# 2018-12-27 23:59:00+00:00  155.847624                 0.117990
# 2018-12-28 23:59:00+00:00  155.847624                 0.294907
# 2018-12-29 23:59:00+00:00    0.000000                 0.249045
# 2018-12-30 23:59:00+00:00 -177.209424                 0.274720
# ...                               ...                      ...
# 2019-03-24 23:59:00+00:00  106.969218                 0.080502
# 2019-03-25 23:59:00+00:00  106.969218                 0.044333
# 2019-03-26 23:59:00+00:00  106.969218                 0.036168
# 2019-03-27 23:59:00+00:00  106.969218                 0.080536
# 2019-03-28 23:59:00+00:00    0.000000                 0.073344
# 2019-03-29 23:59:00+00:00  185.531666                 0.091932
# 2019-03-30 23:59:00+00:00  185.531666                 0.084984
# 2019-03-31 23:59:00+00:00  154.733409                 0.086304
# 2019-04-01 23:59:00+00:00  154.733409                 0.129560
# 2019-04-02 23:59:00+00:00  154.733409                 0.236884
# 2019-04-03 23:59:00+00:00  129.047663                 0.178028
# 2019-04-04 23:59:00+00:00  107.625751                 0.163818
# 2019-04-05 23:59:00+00:00    0.000000                 0.241783
# 2019-04-06 23:59:00+00:00 -175.379248                 0.210722
# 2019-04-07 23:59:00+00:00    0.000000                 0.262595
# 2019-04-08 23:59:00+00:00  164.424227                 0.248037
# 2019-04-09 23:59:00+00:00  164.424227                 0.216802
# 2019-04-10 23:59:00+00:00  164.424227                 0.202522
# 2019-04-11 23:59:00+00:00  164.424227                 0.122229
# 2019-04-12 23:59:00+00:00  164.424227                 0.125856
# 2019-04-13 23:59:00+00:00    0.000000                 0.118477
# 2019-04-14 23:59:00+00:00 -165.694561                 0.108505
# 2019-04-15 23:59:00+00:00 -165.694561                 0.052533
# 2019-04-16 23:59:00+00:00 -165.694561                 0.085609
# 2019-04-17 23:59:00+00:00 -138.189263                 0.075499
# 2019-04-18 23:59:00+00:00 -138.189263                 0.079355
# 2019-04-19 23:59:00+00:00 -138.189263                 0.076958
# 2019-04-20 23:59:00+00:00 -138.189263                 0.084324
# 2019-04-21 23:59:00+00:00 -138.189263                 0.061566
# 2019-04-22 23:59:00+00:00 -138.189263                 0.070947
#
#                            benchmark_volatility      beta  brick_size  \
# 2018-12-01 23:59:00+00:00                   NaN       NaN    0.019292
# 2018-12-02 23:59:00+00:00              0.707629  0.038851    0.019292
# 2018-12-03 23:59:00+00:00              0.926253  0.608079    0.019292
# 2018-12-04 23:59:00+00:00              0.818254  0.691602    0.019292
# 2018-12-05 23:59:00+00:00              0.862644  0.757782    0.019292
# 2018-12-06 23:59:00+00:00              0.928896  0.807837    0.019292
# 2018-12-07 23:59:00+00:00              0.911478  0.834349    0.017043
# 2018-12-08 23:59:00+00:00              0.844372  0.826961    0.017043
# 2018-12-09 23:59:00+00:00              0.883491  0.609465    0.017043
# 2018-12-10 23:59:00+00:00              0.832966  0.608640    0.017043
# 2018-12-11 23:59:00+00:00              0.795545  0.556626    0.017043
# 2018-12-12 23:59:00+00:00              0.813567  0.437538    0.017043
# 2018-12-13 23:59:00+00:00              0.799597  0.317818    0.017043
# 2018-12-14 23:59:00+00:00              0.769527  0.303652    0.017043
# 2018-12-15 23:59:00+00:00              0.779095  0.238743    0.017043
# 2018-12-16 23:59:00+00:00              0.759002  0.237356    0.017043
# 2018-12-17 23:59:00+00:00              0.983424 -0.155399    0.017043
# 2018-12-18 23:59:00+00:00              1.089724 -0.323880    0.017043
# 2018-12-19 23:59:00+00:00              1.069628 -0.353008    0.012195
# 2018-12-20 23:59:00+00:00              1.349548 -0.178897    0.012195
# 2018-12-21 23:59:00+00:00              1.343520 -0.139575    0.012195
# 2018-12-22 23:59:00+00:00              1.324259 -0.099039    0.012195
# 2018-12-23 23:59:00+00:00              1.299426 -0.081695    0.012195
# 2018-12-24 23:59:00+00:00              1.275535 -0.080080    0.012195
# 2018-12-25 23:59:00+00:00              1.272317 -0.052538    0.012195
# 2018-12-26 23:59:00+00:00              1.247151 -0.053672    0.012195
# 2018-12-27 23:59:00+00:00              1.234746 -0.044711    0.012195
# 2018-12-28 23:59:00+00:00              1.293964  0.087138    0.012195
# 2018-12-29 23:59:00+00:00              1.278403  0.091284    0.021524
# 2018-12-30 23:59:00+00:00              1.256497  0.091817    0.021524
# ...                                         ...       ...         ...
# 2019-03-24 23:59:00+00:00              0.843888  0.139169    0.007261
# 2019-03-25 23:59:00+00:00              0.841821  0.140318    0.007261
# 2019-03-26 23:59:00+00:00              0.838272  0.140290    0.007261
# 2019-03-27 23:59:00+00:00              0.836835  0.143147    0.007261
# 2019-03-28 23:59:00+00:00              0.833347  0.143153    0.004716
# 2019-03-29 23:59:00+00:00              0.830110  0.143110    0.004716
# 2019-03-30 23:59:00+00:00              0.826705  0.143148    0.004716
# 2019-03-31 23:59:00+00:00              0.823254  0.143136    0.004716
# 2019-04-01 23:59:00+00:00              0.821647  0.146873    0.004716
# 2019-04-02 23:59:00+00:00              0.828966  0.166557    0.004716
# 2019-04-03 23:59:00+00:00              0.828738  0.171104    0.004716
# 2019-04-04 23:59:00+00:00              0.825653  0.171248    0.004716
# 2019-04-05 23:59:00+00:00              0.827383  0.177001    0.004924
# 2019-04-06 23:59:00+00:00              0.825040  0.176563    0.004924
# 2019-04-07 23:59:00+00:00              0.823703  0.170910    0.010077
# 2019-04-08 23:59:00+00:00              0.820735  0.170775    0.010077
# 2019-04-09 23:59:00+00:00              0.818479  0.172142    0.010077
# 2019-04-10 23:59:00+00:00              0.815573  0.172386    0.010077
# 2019-04-11 23:59:00+00:00              0.818102  0.182448    0.010077
# 2019-04-12 23:59:00+00:00              0.814999  0.182469    0.010077
# 2019-04-13 23:59:00+00:00              0.812017  0.182557    0.011245
# 2019-04-14 23:59:00+00:00              0.809122  0.182451    0.011245
# 2019-04-15 23:59:00+00:00              0.809282  0.173005    0.011245
# 2019-04-16 23:59:00+00:00              0.807313  0.170487    0.011245
# 2019-04-17 23:59:00+00:00              0.804503  0.170045    0.011245
# 2019-04-18 23:59:00+00:00              0.801586  0.170048    0.011245
# 2019-04-19 23:59:00+00:00              0.798716  0.169980    0.011245
# 2019-04-20 23:59:00+00:00              0.795887  0.169941    0.011245
# 2019-04-21 23:59:00+00:00              0.793640  0.168401    0.011245
# 2019-04-22 23:59:00+00:00              0.790899  0.168307    0.011245
#
#                            capital_used  ending_cash           ...            \
# 2018-12-01 23:59:00+00:00      0.000000   100.000000           ...
# 2018-12-02 23:59:00+00:00    -98.172671     1.827329           ...
# 2018-12-03 23:59:00+00:00      0.000000     1.827329           ...
# 2018-12-04 23:59:00+00:00      0.000000     1.827329           ...
# 2018-12-05 23:59:00+00:00      0.000000     1.827329           ...
# 2018-12-06 23:59:00+00:00      0.000000     1.827329           ...
# 2018-12-07 23:59:00+00:00     78.237328    80.064658           ...
# 2018-12-08 23:59:00+00:00     77.298592   157.363249           ...
# 2018-12-09 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-10 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-11 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-12 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-13 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-14 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-15 23:59:00+00:00      0.000000   157.363249           ...
# 2018-12-16 23:59:00+00:00    -12.740731   144.622518           ...
# 2018-12-17 23:59:00+00:00      0.000000   144.622518           ...
# 2018-12-18 23:59:00+00:00      0.000000   144.622518           ...
# 2018-12-19 23:59:00+00:00    -80.903785    63.718733           ...
# 2018-12-20 23:59:00+00:00    -79.424204   -15.705471           ...
# 2018-12-21 23:59:00+00:00      0.000000   -15.705471           ...
# 2018-12-22 23:59:00+00:00     13.054104    -2.651367           ...
# 2018-12-23 23:59:00+00:00      0.000000    -2.651367           ...
# 2018-12-24 23:59:00+00:00      0.000000    -2.651367           ...
# 2018-12-25 23:59:00+00:00     10.470946     7.819579           ...
# 2018-12-26 23:59:00+00:00      0.000000     7.819579           ...
# 2018-12-27 23:59:00+00:00      0.000000     7.819579           ...
# 2018-12-28 23:59:00+00:00      0.000000     7.819579           ...
# 2018-12-29 23:59:00+00:00     55.887209    63.706788           ...
# 2018-12-30 23:59:00+00:00     64.853890   128.560677           ...
# ...                                 ...          ...           ...
# 2019-03-24 23:59:00+00:00      0.000000    24.352879           ...
# 2019-03-25 23:59:00+00:00      0.000000    24.352879           ...
# 2019-03-26 23:59:00+00:00      0.000000    24.352879           ...
# 2019-03-27 23:59:00+00:00      0.000000    24.352879           ...
# 2019-03-28 23:59:00+00:00     32.963419    57.316297           ...
# 2019-03-29 23:59:00+00:00    -58.454722    -1.138425           ...
# 2019-03-30 23:59:00+00:00      0.000000    -1.138425           ...
# 2019-03-31 23:59:00+00:00      9.605319     8.466894           ...
# 2019-04-01 23:59:00+00:00      0.000000     8.466894           ...
# 2019-04-02 23:59:00+00:00      0.000000     8.466894           ...
# 2019-04-03 23:59:00+00:00      8.687245    17.154139           ...
# 2019-04-04 23:59:00+00:00      7.157766    24.311905           ...
# 2019-04-05 23:59:00+00:00     38.370392    62.682297           ...
# 2019-04-06 23:59:00+00:00     60.961682   123.643979           ...
# 2019-04-07 23:59:00+00:00    -63.892215    59.751764           ...
# 2019-04-08 23:59:00+00:00    -59.210543     0.541221           ...
# 2019-04-09 23:59:00+00:00      0.000000     0.541221           ...
# 2019-04-10 23:59:00+00:00      0.000000     0.541221           ...
# 2019-04-11 23:59:00+00:00      0.000000     0.541221           ...
# 2019-04-12 23:59:00+00:00      0.000000     0.541221           ...
# 2019-04-13 23:59:00+00:00     52.799172    53.340393           ...
# 2019-04-14 23:59:00+00:00     52.732740   106.073133           ...
# 2019-04-15 23:59:00+00:00      0.000000   106.073133           ...
# 2019-04-16 23:59:00+00:00      0.000000   106.073133           ...
# 2019-04-17 23:59:00+00:00     -8.535559    97.537574           ...
# 2019-04-18 23:59:00+00:00      0.000000    97.537574           ...
# 2019-04-19 23:59:00+00:00      0.000000    97.537574           ...
# 2019-04-20 23:59:00+00:00      0.000000    97.537574           ...
# 2019-04-21 23:59:00+00:00      0.000000    97.537574           ...
# 2019-04-22 23:59:00+00:00      0.000000    97.537574           ...
#
#                            short_exposure  short_value  shorts_count  \
# 2018-12-01 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-02 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-03 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-04 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-05 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-06 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-07 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-08 23:59:00+00:00      -77.492245   -77.492245             1
# 2018-12-09 23:59:00+00:00      -81.153510   -81.153510             1
# 2018-12-10 23:59:00+00:00      -79.554258   -79.554258             1
# 2018-12-11 23:59:00+00:00      -76.491862   -76.491862             1
# 2018-12-12 23:59:00+00:00      -79.792445   -79.792445             1
# 2018-12-13 23:59:00+00:00      -75.266903   -75.266903             1
# 2018-12-14 23:59:00+00:00      -73.055172   -73.055172             1
# 2018-12-15 23:59:00+00:00      -75.882785   -75.882785             1
# 2018-12-16 23:59:00+00:00      -63.850969   -63.850969             1
# 2018-12-17 23:59:00+00:00      -73.783342   -73.783342             1
# 2018-12-18 23:59:00+00:00      -83.857606   -83.857606             1
# 2018-12-19 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-20 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-21 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-22 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-23 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-24 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-25 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-26 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-27 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-28 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-29 23:59:00+00:00        0.000000     0.000000             0
# 2018-12-30 23:59:00+00:00      -65.016365   -65.016365             1
# ...                                   ...          ...           ...
# 2019-03-24 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-25 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-26 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-27 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-28 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-29 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-30 23:59:00+00:00        0.000000     0.000000             0
# 2019-03-31 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-01 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-02 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-03 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-04 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-05 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-06 23:59:00+00:00      -61.114407   -61.114407             1
# 2019-04-07 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-08 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-09 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-10 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-11 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-12 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-13 23:59:00+00:00        0.000000     0.000000             0
# 2019-04-14 23:59:00+00:00      -52.864850   -52.864850             1
# 2019-04-15 23:59:00+00:00      -50.195510   -50.195510             1
# 2019-04-16 23:59:00+00:00      -51.772922   -51.772922             1
# 2019-04-17 23:59:00+00:00      -42.776487   -42.776487             1
# 2019-04-18 23:59:00+00:00      -42.929877   -42.929877             1
# 2019-04-19 23:59:00+00:00      -42.834526   -42.834526             1
# 2019-04-20 23:59:00+00:00      -43.127487   -43.127487             1
# 2019-04-21 23:59:00+00:00      -42.222348   -42.222348             1
# 2019-04-22 23:59:00+00:00      -42.595459   -42.595459             1
#
#                              sortino  starting_cash  starting_exposure  \
# 2018-12-01 23:59:00+00:00        NaN     100.000000           0.000000
# 2018-12-02 23:59:00+00:00 -11.224972     100.000000           0.000000
# 2018-12-03 23:59:00+00:00  -9.467769       1.827329          97.927753
# 2018-12-04 23:59:00+00:00  -5.873235       1.827329          90.656667
# 2018-12-05 23:59:00+00:00  -8.755931       1.827329          92.633330
# 2018-12-06 23:59:00+00:00 -10.260446       1.827329          85.500000
# 2018-12-07 23:59:00+00:00  -8.757338       1.827329          76.831930
# 2018-12-08 23:59:00+00:00  -8.284538      80.064658           0.000000
# 2018-12-09 23:59:00+00:00  -9.045147     157.363249         -77.492245
# 2018-12-10 23:59:00+00:00  -7.886082     157.363249         -81.153510
# 2018-12-11 23:59:00+00:00  -6.276433     157.363249         -79.554258
# 2018-12-12 23:59:00+00:00  -6.993927     157.363249         -76.491862
# 2018-12-13 23:59:00+00:00  -5.083409     157.363249         -79.792445
# 2018-12-14 23:59:00+00:00  -4.170441     157.363249         -75.266903
# 2018-12-15 23:59:00+00:00  -4.796435     157.363249         -73.055172
# 2018-12-16 23:59:00+00:00  -4.852092     157.363249         -75.882785
# 2018-12-17 23:59:00+00:00  -6.078002     144.622518         -63.850969
# 2018-12-18 23:59:00+00:00  -6.984129     144.622518         -73.783342
# 2018-12-19 23:59:00+00:00  -6.082199     144.622518         -83.857606
# 2018-12-20 23:59:00+00:00  -5.972344      63.718733           0.000000
# 2018-12-21 23:59:00+00:00  -6.620125     -15.705471          79.226060
# 2018-12-22 23:59:00+00:00  -5.407844     -15.705471          74.043507
# 2018-12-23 23:59:00+00:00  -4.643599      -2.651367          65.749384
# 2018-12-24 23:59:00+00:00  -4.786847      -2.651367          68.954165
# 2018-12-25 23:59:00+00:00  -5.334805      -2.651367          67.590031
# 2018-12-26 23:59:00+00:00  -5.255097       7.819579          52.738836
# 2018-12-27 23:59:00+00:00  -5.555361       7.819579          52.612599
# 2018-12-28 23:59:00+00:00  -3.950580       7.819579          50.148649
# 2018-12-29 23:59:00+00:00  -4.210640       7.819579          58.084410
# 2018-12-30 23:59:00+00:00  -4.166570      63.706788           0.000000
# ...                              ...            ...                ...
# 2019-03-24 23:59:00+00:00  -1.831661      24.352879          33.812970
# 2019-03-25 23:59:00+00:00  -1.899760      24.352879          33.266357
# 2019-03-26 23:59:00+00:00  -1.909439      24.352879          32.152808
# 2019-03-27 23:59:00+00:00  -1.803287      24.352879          31.901430
# 2019-03-28 23:59:00+00:00  -1.816636      24.352879          33.267427
# 2019-03-29 23:59:00+00:00  -1.819121      57.316297           0.000000
# 2019-03-30 23:59:00+00:00  -1.837088      -1.138425          58.308892
# 2019-03-31 23:59:00+00:00  -1.826238      -1.138425          57.937829
# 2019-04-01 23:59:00+00:00  -1.684874       8.466894          48.378948
# 2019-04-02 23:59:00+00:00  -1.358075       8.466894          50.305379
# 2019-04-03 23:59:00+00:00  -1.505727       8.466894          55.085094
# 2019-04-04 23:59:00+00:00  -1.533971      17.154139          43.754901
# 2019-04-05 23:59:00+00:00  -1.379559      24.311905          36.051398
# 2019-04-06 23:59:00+00:00  -1.383455      62.682297           0.000000
# 2019-04-07 23:59:00+00:00  -1.536934     123.643979         -61.114407
# 2019-04-08 23:59:00+00:00  -1.540295      59.751764           0.000000
# 2019-04-09 23:59:00+00:00  -1.624263       0.541221          59.062827
# 2019-04-10 23:59:00+00:00  -1.660830       0.541221          57.584653
# 2019-04-11 23:59:00+00:00  -1.871830       0.541221          56.908869
# 2019-04-12 23:59:00+00:00  -1.853066       0.541221          53.109025
# 2019-04-13 23:59:00+00:00  -1.878243       0.541221          53.280648
# 2019-04-14 23:59:00+00:00  -1.880232      53.340393           0.000000
# 2019-04-15 23:59:00+00:00  -1.691692     106.073133         -52.864850
# 2019-04-16 23:59:00+00:00  -1.782313     106.073133         -50.195510
# 2019-04-17 23:59:00+00:00  -1.745426     106.073133         -51.772922
# 2019-04-18 23:59:00+00:00  -1.749090      97.537574         -42.776487
# 2019-04-19 23:59:00+00:00  -1.736620      97.537574         -42.929877
# 2019-04-20 23:59:00+00:00  -1.749261      97.537574         -42.834526
# 2019-04-21 23:59:00+00:00  -1.684327      97.537574         -43.127487
# 2019-04-22 23:59:00+00:00  -1.701899      97.537574         -42.222348
#
#                            starting_value  trading_days  \
# 2018-12-01 23:59:00+00:00        0.000000             1
# 2018-12-02 23:59:00+00:00        0.000000             2
# 2018-12-03 23:59:00+00:00       97.927753             3
# 2018-12-04 23:59:00+00:00       90.656667             4
# 2018-12-05 23:59:00+00:00       92.633330             5
# 2018-12-06 23:59:00+00:00       85.500000             6
# 2018-12-07 23:59:00+00:00       76.831930             7
# 2018-12-08 23:59:00+00:00        0.000000             8
# 2018-12-09 23:59:00+00:00      -77.492245             9
# 2018-12-10 23:59:00+00:00      -81.153510            10
# 2018-12-11 23:59:00+00:00      -79.554258            11
# 2018-12-12 23:59:00+00:00      -76.491862            12
# 2018-12-13 23:59:00+00:00      -79.792445            13
# 2018-12-14 23:59:00+00:00      -75.266903            14
# 2018-12-15 23:59:00+00:00      -73.055172            15
# 2018-12-16 23:59:00+00:00      -75.882785            16
# 2018-12-17 23:59:00+00:00      -63.850969            17
# 2018-12-18 23:59:00+00:00      -73.783342            18
# 2018-12-19 23:59:00+00:00      -83.857606            19
# 2018-12-20 23:59:00+00:00        0.000000            20
# 2018-12-21 23:59:00+00:00       79.226060            21
# 2018-12-22 23:59:00+00:00       74.043507            22
# 2018-12-23 23:59:00+00:00       65.749384            23
# 2018-12-24 23:59:00+00:00       68.954165            24
# 2018-12-25 23:59:00+00:00       67.590031            25
# 2018-12-26 23:59:00+00:00       52.738836            26
# 2018-12-27 23:59:00+00:00       52.612599            27
# 2018-12-28 23:59:00+00:00       50.148649            28
# 2018-12-29 23:59:00+00:00       58.084410            29
# 2018-12-30 23:59:00+00:00        0.000000            30
# ...                                   ...           ...
# 2019-03-24 23:59:00+00:00       33.812970           114
# 2019-03-25 23:59:00+00:00       33.266357           115
# 2019-03-26 23:59:00+00:00       32.152808           116
# 2019-03-27 23:59:00+00:00       31.901430           117
# 2019-03-28 23:59:00+00:00       33.267427           118
# 2019-03-29 23:59:00+00:00        0.000000           119
# 2019-03-30 23:59:00+00:00       58.308892           120
# 2019-03-31 23:59:00+00:00       57.937829           121
# 2019-04-01 23:59:00+00:00       48.378948           122
# 2019-04-02 23:59:00+00:00       50.305379           123
# 2019-04-03 23:59:00+00:00       55.085094           124
# 2019-04-04 23:59:00+00:00       43.754901           125
# 2019-04-05 23:59:00+00:00       36.051398           126
# 2019-04-06 23:59:00+00:00        0.000000           127
# 2019-04-07 23:59:00+00:00      -61.114407           128
# 2019-04-08 23:59:00+00:00        0.000000           129
# 2019-04-09 23:59:00+00:00       59.062827           130
# 2019-04-10 23:59:00+00:00       57.584653           131
# 2019-04-11 23:59:00+00:00       56.908869           132
# 2019-04-12 23:59:00+00:00       53.109025           133
# 2019-04-13 23:59:00+00:00       53.280648           134
# 2019-04-14 23:59:00+00:00        0.000000           135
# 2019-04-15 23:59:00+00:00      -52.864850           136
# 2019-04-16 23:59:00+00:00      -50.195510           137
# 2019-04-17 23:59:00+00:00      -51.772922           138
# 2019-04-18 23:59:00+00:00      -42.776487           139
# 2019-04-19 23:59:00+00:00      -42.929877           140
# 2019-04-20 23:59:00+00:00      -42.834526           141
# 2019-04-21 23:59:00+00:00      -43.127487           142
# 2019-04-22 23:59:00+00:00      -42.222348           143
#
#                                                                 transactions  \
# 2018-12-01 23:59:00+00:00                                                 []
# 2018-12-02 23:59:00+00:00  [{'amount': 333.33333333333337, 'dt': 2018-12-...
# 2018-12-03 23:59:00+00:00                                                 []
# 2018-12-04 23:59:00+00:00                                                 []
# 2018-12-05 23:59:00+00:00                                                 []
# 2018-12-06 23:59:00+00:00                                                 []
# 2018-12-07 23:59:00+00:00  [{'amount': -333.33333333333337, 'dt': 2018-12...
# 2018-12-08 23:59:00+00:00  [{'amount': -340.266288945658, 'dt': 2018-12-0...
# 2018-12-09 23:59:00+00:00                                                 []
# 2018-12-10 23:59:00+00:00                                                 []
# 2018-12-11 23:59:00+00:00                                                 []
# 2018-12-12 23:59:00+00:00                                                 []
# 2018-12-13 23:59:00+00:00                                                 []
# 2018-12-14 23:59:00+00:00                                                 []
# 2018-12-15 23:59:00+00:00                                                 []
# 2018-12-16 23:59:00+00:00  [{'amount': 56.48420396497926, 'dt': 2018-12-1...
# 2018-12-17 23:59:00+00:00                                                 []
# 2018-12-18 23:59:00+00:00                                                 []
# 2018-12-19 23:59:00+00:00  [{'amount': 283.78208498067875, 'dt': 2018-12-...
# 2018-12-20 23:59:00+00:00  [{'amount': 224.06193630410942, 'dt': 2018-12-...
# 2018-12-21 23:59:00+00:00                                                 []
# 2018-12-22 23:59:00+00:00  [{'amount': -37.19428142648218, 'dt': 2018-12-...
# 2018-12-23 23:59:00+00:00                                                 []
# 2018-12-24 23:59:00+00:00                                                 []
# 2018-12-25 23:59:00+00:00  [{'amount': -31.020030709686125, 'dt': 2018-12...
# 2018-12-26 23:59:00+00:00                                                 []
# 2018-12-27 23:59:00+00:00                                                 []
# 2018-12-28 23:59:00+00:00                                                 []
# 2018-12-29 23:59:00+00:00  [{'amount': -155.84762416794112, 'dt': 2018-12...
# 2018-12-30 23:59:00+00:00  [{'amount': -177.20942366017965, 'dt': 2018-12...
# ...                                                                      ...
# 2019-03-24 23:59:00+00:00                                                 []
# 2019-03-25 23:59:00+00:00                                                 []
# 2019-03-26 23:59:00+00:00                                                 []
# 2019-03-27 23:59:00+00:00                                                 []
# 2019-03-28 23:59:00+00:00  [{'amount': -106.96921843573648, 'dt': 2019-03...
# 2019-03-29 23:59:00+00:00  [{'amount': 185.5316657154698, 'dt': 2019-03-2...
# 2019-03-30 23:59:00+00:00                                                 []
# 2019-03-31 23:59:00+00:00  [{'amount': -30.79825650876799, 'dt': 2019-03-...
# 2019-04-01 23:59:00+00:00                                                 []
# 2019-04-02 23:59:00+00:00                                                 []
# 2019-04-03 23:59:00+00:00  [{'amount': -25.685745928312514, 'dt': 2019-04...
# 2019-04-04 23:59:00+00:00  [{'amount': -21.421912104212623, 'dt': 2019-04...
# 2019-04-05 23:59:00+00:00  [{'amount': -107.62575117417668, 'dt': 2019-04...
# 2019-04-06 23:59:00+00:00  [{'amount': -175.37924799469752, 'dt': 2019-04...
# 2019-04-07 23:59:00+00:00  [{'amount': 175.37924799469752, 'dt': 2019-04-...
# 2019-04-08 23:59:00+00:00  [{'amount': 164.42422721969425, 'dt': 2019-04-...
# 2019-04-09 23:59:00+00:00                                                 []
# 2019-04-10 23:59:00+00:00                                                 []
# 2019-04-11 23:59:00+00:00                                                 []
# 2019-04-12 23:59:00+00:00                                                 []
# 2019-04-13 23:59:00+00:00  [{'amount': -164.42422721969425, 'dt': 2019-04...
# 2019-04-14 23:59:00+00:00  [{'amount': -165.69456051975547, 'dt': 2019-04...
# 2019-04-15 23:59:00+00:00                                                 []
# 2019-04-16 23:59:00+00:00                                                 []
# 2019-04-17 23:59:00+00:00  [{'amount': 27.505297046279424, 'dt': 2019-04-...
# 2019-04-18 23:59:00+00:00                                                 []
# 2019-04-19 23:59:00+00:00                                                 []
# 2019-04-20 23:59:00+00:00                                                 []
# 2019-04-21 23:59:00+00:00                                                 []
# 2019-04-22 23:59:00+00:00                                                 []
#
#                            treasury_period_return
# 2018-12-01 23:59:00+00:00                   0.001
# 2018-12-02 23:59:00+00:00                   0.001
# 2018-12-03 23:59:00+00:00                   0.001
# 2018-12-04 23:59:00+00:00                   0.001
# 2018-12-05 23:59:00+00:00                   0.001
# 2018-12-06 23:59:00+00:00                   0.001
# 2018-12-07 23:59:00+00:00                   0.001
# 2018-12-08 23:59:00+00:00                   0.001
# 2018-12-09 23:59:00+00:00                   0.001
# 2018-12-10 23:59:00+00:00                   0.001
# 2018-12-11 23:59:00+00:00                   0.001
# 2018-12-12 23:59:00+00:00                   0.001
# 2018-12-13 23:59:00+00:00                   0.001
# 2018-12-14 23:59:00+00:00                   0.001
# 2018-12-15 23:59:00+00:00                   0.001
# 2018-12-16 23:59:00+00:00                   0.001
# 2018-12-17 23:59:00+00:00                   0.001
# 2018-12-18 23:59:00+00:00                   0.001
# 2018-12-19 23:59:00+00:00                   0.001
# 2018-12-20 23:59:00+00:00                   0.001
# 2018-12-21 23:59:00+00:00                   0.001
# 2018-12-22 23:59:00+00:00                   0.001
# 2018-12-23 23:59:00+00:00                   0.001
# 2018-12-24 23:59:00+00:00                   0.001
# 2018-12-25 23:59:00+00:00                   0.001
# 2018-12-26 23:59:00+00:00                   0.001
# 2018-12-27 23:59:00+00:00                   0.001
# 2018-12-28 23:59:00+00:00                   0.001
# 2018-12-29 23:59:00+00:00                   0.001
# 2018-12-30 23:59:00+00:00                   0.001
# ...                                           ...
# 2019-03-24 23:59:00+00:00                   0.001
# 2019-03-25 23:59:00+00:00                   0.001
# 2019-03-26 23:59:00+00:00                   0.001
# 2019-03-27 23:59:00+00:00                   0.001
# 2019-03-28 23:59:00+00:00                   0.001
# 2019-03-29 23:59:00+00:00                   0.001
# 2019-03-30 23:59:00+00:00                   0.001
# 2019-03-31 23:59:00+00:00                   0.001
# 2019-04-01 23:59:00+00:00                   0.001
# 2019-04-02 23:59:00+00:00                   0.001
# 2019-04-03 23:59:00+00:00                   0.001
# 2019-04-04 23:59:00+00:00                   0.001
# 2019-04-05 23:59:00+00:00                   0.001
# 2019-04-06 23:59:00+00:00                   0.001
# 2019-04-07 23:59:00+00:00                   0.001
# 2019-04-08 23:59:00+00:00                   0.001
# 2019-04-09 23:59:00+00:00                   0.001
# 2019-04-10 23:59:00+00:00                   0.001
# 2019-04-11 23:59:00+00:00                   0.001
# 2019-04-12 23:59:00+00:00                   0.001
# 2019-04-13 23:59:00+00:00                   0.001
# 2019-04-14 23:59:00+00:00                   0.001
# 2019-04-15 23:59:00+00:00                   0.001
# 2019-04-16 23:59:00+00:00                   0.001
# 2019-04-17 23:59:00+00:00                   0.001
# 2019-04-18 23:59:00+00:00                   0.001
# 2019-04-19 23:59:00+00:00                   0.001
# 2019-04-20 23:59:00+00:00                   0.001
# 2019-04-21 23:59:00+00:00                   0.001
# 2019-04-22 23:59:00+00:00                   0.001
#
# [143 rows x 44 columns]

# %%
# !catalyst ingest-exchange -x bitfinex -f daily -i iot_usd
# Out:
# Trying to ingest exchange bundle bitfinex...
# Ingesting daily price data on bitfinex

# %%
# !catalyst ingest-exchange -x bitfinex -f minute -i iot_usd
# Out:
# Trying to ingest exchange bundle bitfinex...
# Ingesting minute price data on bitfinex

# %%
df=pd.read_csv("perf_TradingPair(652614 [iot_usd]).csv")

# %% [markdown]
# list(df.columns)

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'algo_volatility',
#  'algorithm_period_return',
#  'alpha',
#  'amount',
#  'benchmark_period_return',
#  'benchmark_volatility',
#  'beta',
#  'brick_size',
#  'capital_used',
#  'ending_cash',
#  'ending_exposure',
#  'ending_value',
#  'excess_return',
#  'gross_leverage',
#  'information',
#  'long_exposure',
#  'long_value',
#  'longs_count',
#  'max_drawdown',
#  'max_leverage',
#  'net_leverage',
#  'num_created_bars',
#  'orders',
#  'period_close',
#  'period_label',
#  'period_open',
#  'pnl',
#  'portfolio_value',
#  'positions',
#  'price',
#  'rebuilding_status',
#  'renko_price',
#  'returns',
#  'sharpe',
#  'short_exposure',
#  'short_value',
#  'shorts_count',
#  'sortino',
#  'starting_cash',
#  'starting_exposure',
#  'starting_value',
#  'trading_days',
#  'transactions',
#  'treasury_period_return']

# %%
(df['pnl'])
# Out:
# 0       0.000000
# 1      -0.244917
# 2      -7.271087
# 3       1.976663
# 4      -7.133330
# 5      -8.668070
# 6       1.405398
# 7      -0.193653
# 8      -3.661265
# 9       1.599252
# 10      3.062397
# 11     -3.300583
# 12      4.525542
# 13      2.211731
# 14     -2.827613
# 15     -0.708915
# 16     -9.932373
# 17    -10.074264
# 18      2.953821
# 19     -0.198144
# 20     -5.182553
# 21      4.759981
# 22      3.204780
# 23     -1.364134
# 24     -4.380249
# 25     -0.126237
# 26     -2.463951
# 27      7.935761
# 28     -2.197201
# 29     -0.162476
#          ...
# 113    -0.546613
# 114    -1.113550
# 115    -0.251378
# 116     1.365997
# 117    -0.304008
# 118    -0.145831
# 119    -0.371063
# 120     0.046438
# 121     1.926431
# 122     4.779715
# 123    -2.642948
# 124    -0.545737
# 125     2.318994
# 126    -0.152725
# 127    -2.777808
# 128    -0.147716
# 129    -1.478174
# 130    -0.675784
# 131    -3.799844
# 132     0.171623
# 133    -0.481477
# 134    -0.132109
# 135     2.669339
# 136    -1.577412
# 137     0.460877
# 138    -0.153390
# 139     0.095351
# 140    -0.292961
# 141     0.905140
# 142    -0.373111
# Name: pnl, dtype: float64
